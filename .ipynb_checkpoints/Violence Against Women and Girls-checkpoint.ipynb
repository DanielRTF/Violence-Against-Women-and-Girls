# %% [markdown]
# ## Table of Contents

# %% [markdown]
# ## Goals
# This notebook contains an analysis on Violence Against Women and Girls data. The goal for this project was to do the following:
# * Get acquainted with the data
# *
# Clean the data so it is ready for analysi
# * Develop some questions for analysis
# * Analyze variables within the data to gain patterns and insights on these questionsons

# %% [markdown]
# ## Data
# The data for this project was downloaded from Kaggle:
#
# https://www.kaggle.com/datasets/andrewmvd/violence-against-women-and-girls?resource=download
#
# Information regarding the features for the data are located in the `Column` section on the website.

# %% [markdown]
# ## Loading Data

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import re
from IPython.display import display

# %%
violence_data = pd.read_csv('violence_data.csv')
violence_data.head(10)
# Out:
#    RecordID      Country Gender Demographics Question  \
# 0         1  Afghanistan      F        Marital status
# 1         1  Afghanistan      F             Education
# 2         1  Afghanistan      F             Education
# 3         1  Afghanistan      F             Education
# 4         1  Afghanistan      F        Marital status
# 5         1  Afghanistan      F            Employment
# 6         1  Afghanistan      F                   Age
# 7         1  Afghanistan      F            Employment
# 8         1  Afghanistan      F             Residence
# 9         1  Afghanistan      F                   Age
#
#           Demographics Response                   Question Survey Year  Value
# 0                 Never married  ... if she burns the food  01/01/2015    NaN
# 1                        Higher  ... if she burns the food  01/01/2015   10.1
# 2                     Secondary  ... if she burns the food  01/01/2015   13.7
# 3                       Primary  ... if she burns the food  01/01/2015   13.8
# 4  Widowed, divorced, separated  ... if she burns the food  01/01/2015   13.8
# 5             Employed for kind  ... if she burns the food  01/01/2015   17.0
# 6                         15-24  ... if she burns the food  01/01/2015   17.3
# 7                    Unemployed  ... if she burns the food  01/01/2015   18.0
# 8                         Rural  ... if she burns the food  01/01/2015   18.1
# 9                         25-34  ... if she burns the food  01/01/2015   18.2

# %%
violence_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12600 entries, 0 to 12599
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   RecordID               12600 non-null  int64
#  1   Country                12600 non-null  object
#  2   Gender                 12600 non-null  object
#  3   Demographics Question  12600 non-null  object
#  4   Demographics Response  12600 non-null  object
#  5   Question               12600 non-null  object
#  6   Survey Year            12600 non-null  object
#  7   Value                  11187 non-null  float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 787.6+ KB

# %%
violence_data.nunique()
# Out:
# RecordID                 420
# Country                   70
# Gender                     2
# Demographics Question      5
# Demographics Response     15
# Question                   6
# Survey Year               18
# Value                    757
# dtype: int64

# %%
violence_data.isnull().sum()
# Out:
# RecordID                    0
# Country                     0
# Gender                      0
# Demographics Question       0
# Demographics Response       0
# Question                    0
# Survey Year                 0
# Value                    1413
# dtype: int64

# %%
violence_data.columns
# Out:
# Index(['RecordID', 'Country', 'Gender', 'Demographics Question',
#        'Demographics Response', 'Question', 'Survey Year', 'Value'],
#       dtype='object')

# %%
violence_data.describe()
# Out:
#            RecordID         Value
# count  12600.000000  11187.000000
# mean     210.500000     19.762537
# std      121.248024     16.986437
# min        1.000000      0.000000
# 25%      105.750000      6.200000
# 50%      210.500000     14.900000
# 75%      315.250000     29.200000
# max      420.000000     86.900000

# %% [markdown]
# ## Data Information
# Some immediate insights are:
# * There are 8 columns and 12600 rows.
# * The name and datatype of each column most values are strings in this data set.
# * We have missing data is in the Value column.

# %% [markdown]
# ## Data Cleaning
# As mentioned before, the `Value` column has missing data. We exactly have 1413 missing values in this column, it represents approximately the 11%. Even though is big percentage of missing data. We have decided to use `Listwise Deleteion`, because we consider this data as `Missing At Random` data, also known as `MAR`.

# %%
violence_data.dropna(inplace=True)

# %%
violence_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11187 entries, 1 to 12599
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   RecordID               11187 non-null  int64
#  1   Country                11187 non-null  object
#  2   Gender                 11187 non-null  object
#  3   Demographics Question  11187 non-null  object
#  4   Demographics Response  11187 non-null  object
#  5   Question               11187 non-null  object
#  6   Survey Year            11187 non-null  object
#  7   Value                  11187 non-null  float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 786.6+ KB

# %% [markdown]
# For this project we are interested in `women's mentality`, so we will take only female's answers.
# In order to do that we will filter the `gender` column.

# %%
female = violence_data[violence_data['Gender'] == 'F']
female.head(20)
# Out:
#     RecordID      Country Gender Demographics Question  \
# 1          1  Afghanistan      F             Education
# 2          1  Afghanistan      F             Education
# 3          1  Afghanistan      F             Education
# 4          1  Afghanistan      F        Marital status
# 5          1  Afghanistan      F            Employment
# 6          1  Afghanistan      F                   Age
# 7          1  Afghanistan      F            Employment
# 8          1  Afghanistan      F             Residence
# 9          1  Afghanistan      F                   Age
# 10         1  Afghanistan      F        Marital status
# 11         1  Afghanistan      F             Residence
# 12         1  Afghanistan      F                   Age
# 13         1  Afghanistan      F             Education
# 14         1  Afghanistan      F            Employment
# 30       351  Afghanistan      F                   Age
# 31       351  Afghanistan      F                   Age
# 32       351  Afghanistan      F                   Age
# 33        71  Afghanistan      F                   Age
# 34        71  Afghanistan      F                   Age
# 35        71  Afghanistan      F                   Age
#
#            Demographics Response                              Question  \
# 1                         Higher             ... if she burns the food
# 2                      Secondary             ... if she burns the food
# 3                        Primary             ... if she burns the food
# 4   Widowed, divorced, separated             ... if she burns the food
# 5              Employed for kind             ... if she burns the food
# 6                          15-24             ... if she burns the food
# 7                     Unemployed             ... if she burns the food
# 8                          Rural             ... if she burns the food
# 9                          25-34             ... if she burns the food
# 10    Married or living together             ... if she burns the food
# 11                         Urban             ... if she burns the food
# 12                         35-49             ... if she burns the food
# 13                  No education             ... if she burns the food
# 14             Employed for cash             ... if she burns the food
# 30                         15-24  ... for at least one specific reason
# 31                         25-34  ... for at least one specific reason
# 32                         35-49  ... for at least one specific reason
# 33                         15-24            ... if she argues with him
# 34                         25-34            ... if she argues with him
# 35                         35-49            ... if she argues with him
#
#    Survey Year  Value
# 1   01/01/2015   10.1
# 2   01/01/2015   13.7
# 3   01/01/2015   13.8
# 4   01/01/2015   13.8
# 5   01/01/2015   17.0
# 6   01/01/2015   17.3
# 7   01/01/2015   18.0
# 8   01/01/2015   18.1
# 9   01/01/2015   18.2
# 10  01/01/2015   18.3
# 11  01/01/2015   18.3
# 12  01/01/2015   18.8
# 13  01/01/2015   19.1
# 14  01/01/2015   20.8
# 30  01/01/2015   80.1
# 31  01/01/2015   81.5
# 32  01/01/2015   79.0
# 33  01/01/2015   57.5
# 34  01/01/2015   60.0
# 35  01/01/2015   59.8

# %% [markdown]
# Now we will create some data sets based on the `Demographics Question` column, in order to have a data set per demographic group. With this we can do a better analysis.

# %%
female['Demographics Question'].unique()
# Out:
# array(['Education', 'Marital status', 'Employment', 'Age', 'Residence'],
#       dtype=object)

# %%
female_age = female[female['Demographics Question'] == 'Age']
female_edu = female[female['Demographics Question'] == 'Education']
female_marital = female[female['Demographics Question'] == 'Marital status']
female_employ = female[female['Demographics Question'] == 'Employment']
female_residence = female[female['Demographics Question'] == 'Residence']
display(female_age.head())
display(female_edu.head())
display(female_marital.head())
display(female_employ.head())
display(female_residence.head())
# Out:
#     RecordID      Country Gender Demographics Question Demographics Response  \
# 6          1  Afghanistan      F                   Age                 15-24
# 9          1  Afghanistan      F                   Age                 25-34
# 12         1  Afghanistan      F                   Age                 35-49
# 30       351  Afghanistan      F                   Age                 15-24
# 31       351  Afghanistan      F                   Age                 25-34
#
#                                 Question Survey Year  Value
# 6              ... if she burns the food  01/01/2015   17.3
# 9              ... if she burns the food  01/01/2015   18.2
# 12             ... if she burns the food  01/01/2015   18.8
# 30  ... for at least one specific reason  01/01/2015   80.1
# 31  ... for at least one specific reason  01/01/2015   81.5
#     RecordID      Country Gender Demographics Question Demographics Response  \
# 1          1  Afghanistan      F             Education                Higher
# 2          1  Afghanistan      F             Education             Secondary
# 3          1  Afghanistan      F             Education               Primary
# 13         1  Afghanistan      F             Education          No education
# 45       351  Afghanistan      F             Education                Higher
#
#                                 Question Survey Year  Value
# 1              ... if she burns the food  01/01/2015   10.1
# 2              ... if she burns the food  01/01/2015   13.7
# 3              ... if she burns the food  01/01/2015   13.8
# 13             ... if she burns the food  01/01/2015   19.1
# 45  ... for at least one specific reason  01/01/2015   61.1
#     RecordID      Country Gender Demographics Question  \
# 4          1  Afghanistan      F        Marital status
# 10         1  Afghanistan      F        Marital status
# 80       351  Afghanistan      F        Marital status
# 82       351  Afghanistan      F        Marital status
# 83        71  Afghanistan      F        Marital status
#
#            Demographics Response                              Question  \
# 4   Widowed, divorced, separated             ... if she burns the food
# 10    Married or living together             ... if she burns the food
# 80    Married or living together  ... for at least one specific reason
# 82  Widowed, divorced, separated  ... for at least one specific reason
# 83    Married or living together            ... if she argues with him
#
#    Survey Year  Value
# 4   01/01/2015   13.8
# 10  01/01/2015   18.3
# 80  01/01/2015   80.6
# 82  01/01/2015   67.6
# 83  01/01/2015   59.5
#     RecordID      Country Gender Demographics Question Demographics Response  \
# 5          1  Afghanistan      F            Employment     Employed for kind
# 7          1  Afghanistan      F            Employment            Unemployed
# 14         1  Afghanistan      F            Employment     Employed for cash
# 65       351  Afghanistan      F            Employment     Employed for cash
# 66       351  Afghanistan      F            Employment     Employed for kind
#
#                                 Question Survey Year  Value
# 5              ... if she burns the food  01/01/2015   17.0
# 7              ... if she burns the food  01/01/2015   18.0
# 14             ... if she burns the food  01/01/2015   20.8
# 65  ... for at least one specific reason  01/01/2015   80.2
# 66  ... for at least one specific reason  01/01/2015   86.9
#     RecordID      Country Gender Demographics Question Demographics Response  \
# 8          1  Afghanistan      F             Residence                 Rural
# 11         1  Afghanistan      F             Residence                 Urban
# 95       351  Afghanistan      F             Residence                 Rural
# 96       351  Afghanistan      F             Residence                 Urban
# 97        71  Afghanistan      F             Residence                 Rural
#
#                                 Question Survey Year  Value
# 8              ... if she burns the food  01/01/2015   18.1
# 11             ... if she burns the food  01/01/2015   18.3
# 95  ... for at least one specific reason  01/01/2015   82.1
# 96  ... for at least one specific reason  01/01/2015   74.0
# 97            ... if she argues with him  01/01/2015   60.6

# %%
display(female_age['Demographics Response'].unique())
display(female_edu['Demographics Response'].unique())
display(female_marital['Demographics Response'].unique())
display(female_employ['Demographics Response'].unique())
display(female_residence['Demographics Response'].unique())
# Out:
# array(['15-24', '25-34', '35-49'], dtype=object)
# array(['Higher', 'Secondary', 'Primary', 'No education'], dtype=object)
# array(['Widowed, divorced, separated', 'Married or living together',
#        'Never married'], dtype=object)
# array(['Employed for kind', 'Unemployed', 'Employed for cash'],
#       dtype=object)
# array(['Rural', 'Urban'], dtype=object)

# %% [markdown]
# ### For this project, it has been decided to work with the `female_residence` dataframe, to analyze the different mentality between women who live in rural and urban areas, in different regions around the world.
